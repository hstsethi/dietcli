# %%
# !git clone --depth=1 https://github.com/hstsethi/dietcli
# This JSON test data seems to be causing errors
#!wget -O "dietcli/src/large.json" https://github.com/json-iterator/test-data/raw/refs/heads/master/large-file.json
#!cat dietcli/src/consumed.json dietcli/src/large.json > dietcli/src/consumed.json.bak
#!mv dietcli/src/consumed.json.bak dietcli/src/consumed.json
# !apt install gcc rapidjson-dev
# Out:
# Cloning into 'dietcli'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 20 (delta 0), reused 12 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (20/20), 31.85 KiB | 5.31 MiB/s, done.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# gcc is already the newest version (4:11.2.0-1ubuntu1).
# rapidjson-dev is already the newest version (1.1.0+dfsg2-7).
# 0 upgraded, 0 newly installed, 0 to remove and 132 not upgraded.

# %%
# %cd dietcli/src/
# !g++ *.cpp -o dietcli.bin
# !time ./dietcli.bin vit > /dev/null
# Out:
# [Errno 2] No such file or directory: 'dietcli/src/'
# /kaggle/working/dietcli/src/dietcli/src
#
# real	0m0.003s
# user	0m0.001s
# sys	0m0.002s
